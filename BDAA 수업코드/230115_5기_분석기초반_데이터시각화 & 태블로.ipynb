# %% [markdown]
# ### 1. 반복문을 통한 다양한 시각화 그래프 그리기

# %%
import pandas as pd
mpg = pd.read_csv('mpg.csv')

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#시각화를 반복문을 통해 그리려면 도화지가 여러 개 필요하다!
#gridspec

import matplotlib.gridspec as gridspec
grid = gridspec.GridSpec(2,2)#그래프를 그릴 도화지 개수
plt.figure(figsize=(15,10))
plt.subplots_adjust(wspace= 0.4, hspace=0.3) #그래프 간의 거리 조절

#서버플롯 그리기
## sns countplot으로 그래프 그리기 ( x에 대한 카운트를 그래프로 그리고 범례도 설정할 수 있다)

mpg_features = ['manufacturer','model','category','drv']

for idx, feature in enumerate(mpg_features):
    ax = plt.subplot(grid[idx])
    
    sns.countplot(x=feature,
                 data= mpg,
                 hue='drv',
                 palette = 'pastel',
                 ax= ax)

    ax.set_title(f'{feature} Distribution')

# %%
## 만약 설치 안 되면
pip install -U finance-datareader

# %%
import FinanceDataReader as fdr

# %%
df_krx = fdr.StockListing('KRX') #KRX는 전체를 가지고 옴
df_krx.Market.value_counts()
# Out:
# KOSPI            4704
# KOSDAQ           1575
# KONEX             132
# KOSDAQ GLOBAL      51
# Name: Market, dtype: int64

# %%
df_krx.Market.value_counts()

# %%
df_krx.Name.value_counts()
# Out:
# 한국HY12KOSPI200풋       1
# 일진전기                  1
# KBHL02KOSPI200풋       1
# KODEX 23-12 국고채액티브    1
# 미래HZ31KOSPI200풋       1
#                      ..
# ACE 국채선물3년인버스         1
# KBHN53KOSPI200콜       1
# 대창솔루션                 1
# 하이록코리아                1
# KBJQ23KOSPI200풋       1
# Name: Name, Length: 6462, dtype: int64

# %% [markdown]
# ## 설 필수과제
# - fdr 데이터를 가지고
# - 내가 원하는 기업을 분석해 주시면 되는데, 단순히 하나의 기업이 아닌, 경쟁사(선도기업일 수 있고), 전체 시장에 대한 경쟁사 등 다양한 것을 고려해서 비교가능성이 보일 수 있도록 분석해 주세요!
# - 시각화 필수
# - 기본적인 전처리도 필수입니다.
#
# - 반복문을 통해서 최소 5개 이상 시각화해주세요! (컬럼은 최소 4개 이상으로!)
# - 재무제표만 가지고 해당 재무성과를 판단하기는 어려울 수 있다.
# - 비재무데이터, 신문이나, 뉴스나 등등 해당 분석 과정에서 이상한 점이 발견한다면, 재무외에 비재무적 데이터도 서칭해서
# - 함께 제시해 주세요!

# %%
df_krx
# Out:
#       Symbol  Market                     Name         Sector  \
# 0     060310  KOSDAQ                       3S       전자부품 제조업
# 1     105190   KOSPI                  ACE 200            NaN
# 2     332500   KOSPI                ACE 200TR            NaN
# 3     448870   KOSPI  ACE 23-12 회사채(AA-이상)액티브            NaN
# 4     448880   KOSPI  ACE 24-12 회사채(AA-이상)액티브            NaN
# ...      ...     ...                      ...            ...
# 6457  435550   KOSPI          히어로즈 TDF2050액티브            NaN
# 6458  437550   KOSPI         히어로즈 글로벌리츠이지스액티브            NaN
# 6459  419890   KOSPI          히어로즈 단기채권ESG액티브            NaN
# 6460  429870   KOSPI            히어로즈 리츠이지스액티브            NaN
# 6461  238490  KOSDAQ                       힘스  특수 목적용 기계 제조업
#
#                             Industry ListingDate SettleMonth Representative  \
# 0                        반도체 웨이퍼 캐리어  2002-04-23         03월            김세완
# 1                                NaN         NaT         NaN            NaN
# ...

# %% [markdown]
# ### 해당 기업에 대해서
# - 재무제표 데이터 또는 주가 데이터를 직접 서칭하거나, 구글링을 통해서 불러와주세요!
# - 주가 불러오는 방법
# - 위의 데이터에서 Symbol 값과 원하는 기준 연도를 적으면 가장 최근 연도까지 데이터를 불러옵니다!

# %%
# 2021년~현재까지의 네이버 주가를 데이터 프레임으로 불러오기
df_naver = fdr.DataReader('060310', '2023') # 해당 기업 symbol, 기준 연도

# 가장 마지막(최신)의 10일치 주가 출력
df_naver.tail(10)
# Out:
#             Open  High   Low  Close  Volume    Change
# Date
# 2023-01-02  2100  2125  1995   2020  300743 -0.035800
# 2023-01-03  2000  2045  1930   2010  316570 -0.004950
# 2023-01-04  2025  2140  2000   2125  217247  0.057214
# 2023-01-05  2130  2150  2100   2110   88408 -0.007059
# 2023-01-06  2110  2185  2075   2185  110979  0.035545
# 2023-01-09  2195  2270  2195   2240  167917  0.025172
# 2023-01-10  2240  2255  2225   2255   89487  0.006696
# 2023-01-11  2260  2285  2245   2250   79094 -0.002217
# 2023-01-12  2250  2265  2230   2250  105930  0.000000
# 2023-01-13  2230  2280  2230   2250  104725  0.000000
