# %% [markdown]
# ## 데이터프레임과 시리즈에 대해서 확인하기 !

# %%
import pandas as pd

# %%
df_cl = pd.DataFrame({'class':['1반','2반','3반'],
                    'name':['홍길동','김영희','김철수'],
                    '영어':[50,60,70],
                     '수학':[100,90,80]})

# %%
df_cl
# Out:
#   class name  영어   수학
# 0    1반  홍길동  50  100
# 1    2반  김영희  60   90
# 2    3반  김철수  70   80

# %% [markdown]
# ### 시리즈를 접근하기!

# %%
clel= df_cl['영어']

# %%
clel
# Out:
# 0    50
# 1    60
# 2    70
# Name: 영어, dtype: int64

# %% [markdown]
# ### 시리즈의 메서드
# - append : 2개 이상의 시리즈 연결
# - describe : 요약통계
# - drop_duplicates : 중복값 없는 시리즈 반환
# - equals : 시리즈에 해당 값 가진 요소 확인
# - get_values : 시리즈 값 구하기 ( values와 같음)
# - isin
# - min
# - max
# - mean
# - std, var
# - median
# - replace : 특정값을 가진 시리즈 값을 교체
# - sort_values 정렬
# - to_frame

# %% [markdown]
# ### 과제1
# - 데이터프레임을 직접 만들고 위의 시리즈 메서드를 모두 사용해 주세요!

# %%
clel.mean()
# Out:
# 60.0

# %%
clel.to_frame()
# Out:
#    영어
# 0  50
# 1  60
# 2  70

# %%
mpg = pd.read_csv('../dataset/mpg .csv')

# %%
mpg_cty = mpg['cty']
mpg_cty
# Out:
# 0      18
# 1      21
# 2      20
# 3      21
# 4      16
#        ..
# 229    19
# 230    21
# 231    16
# 232    18
# 233    17
# Name: cty, Length: 234, dtype: int64

# %%
mpg_hwy = mpg['hwy']
mpg_hwy
# Out:
# 0      29
# 1      29
# 2      31
# 3      30
# 4      26
#        ..
# 229    28
# 230    29
# 231    26
# 232    26
# 233    26
# Name: hwy, Length: 234, dtype: int64

# %%
mpg_cty + clel #두 시리즈가 길이가 맞지 않으면 na값이 된다.
# Out:
# 0      68.0
# 1      81.0
# 2      90.0
# 3       NaN
# 4       NaN
#        ...
# 229     NaN
# 230     NaN
# 231     NaN
# 232     NaN
# 233     NaN
# Length: 234, dtype: float64

# %%
mpg_cty + mpg_hwy
# Out:
# 0      47
# 1      50
# 2      51
# 3      51
# 4      42
#        ..
# 229    47
# 230    50
# 231    42
# 232    44
# 233    43
# Length: 234, dtype: int64

# %%
mpg_hwy
# Out:
# 0      29
# 1      29
# 2      31
# 3      30
# 4      26
#        ..
# 229    28
# 230    29
# 231    26
# 232    26
# 233    26
# Name: hwy, Length: 234, dtype: int64

# %%
mpg_hwy *2
# Out:
# 0      58
# 1      58
# 2      62
# 3      60
# 4      52
#        ..
# 229    56
# 230    58
# 231    52
# 232    52
# 233    52
# Name: hwy, Length: 234, dtype: int64

# %% [markdown]
# ### 데이터프레임

# %%
mpg[mpg['cty']>mpg['cty'].mean()]
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6  manual(m5)   f   18   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 228   volkswagen  passat    1.8  1999    4    auto(l5)   f   18   29  p
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#     category
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 5    compact
# ..       ...
# 228  midsize
# 229  midsize
# 230  midsize
# 232  midsize
# 233  midsize
#
# [118 rows x 11 columns]

# %% [markdown]
# # 데이터 시각화
#
# - matplot, seaborn 두 개 정도로 대부분 사용
# - 시각화는 목적이 있어야지만 의미가 있다.
# - 시각화는 나의 가설, 내가 설득하고 싶을 때 사용하는 것
# - 시각화는 나의 가설, 나의 주장, 나의 설득과 잘 연결되고 그것을 잘 표현해야 한다.

# %%
#그래프를 그리는 기초
from matplotlib import pyplot as plt

# %%
#산점도를 그려보자!
plt.scatter([1,2,3],[4,5,6])
plt.show()

# %%
#산점도를 그려보자!
plt.scatter([1,2,3],[4,5,6])
plt.scatter([1.5,7],[8,9])
plt.show()

# %% [markdown]
# %matplotlib inline
# - 매직커맨드 show 함수 사용하지 않아도 그래프 출력!

# %%
# %matplotlib inline

# %%
plt.scatter([1,2,3],[4,5,6])

# %% [markdown]
# ## 그래프 제목 및 축 이름 설정

# %%
plt.scatter([1,2,3],[4,5,6])
plt.title('Hi') # 제목
plt.xlabel('x axis')
plt.ylabel('y axis')
# Out:
# Text(0, 0.5, 'y axis')

# %%
plt.scatter([1,2,3],[4,5,6])
plt.title('예제') # 제목
plt.xlabel('x axis')
plt.ylabel('y axis')
# Out:
# Text(0, 0.5, 'y axis')
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/events.py:89: UserWarning: Glyph 50696 (\N{HANGUL SYLLABLE YE}) missing from current font.
#   func(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/events.py:89: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from current font.
#   func(*args, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 50696 (\N{HANGUL SYLLABLE YE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ### 축 범위 설정
# - xlim
# - ylim

# %%
plt.scatter([1,2,3],[4,5,6])
plt.title('Title') # 제목
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.xlim(0,2)
plt.ylim(4,5)
# Out:
# (4.0, 5.0)

# %%
plt.scatter([1,2,3],[4,5,6])
plt.title('Title') # 제목
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.xlim(left = 0.25) #왼쪽 기준으로 보여주기!
plt.ylim(top=5)
# Out:
# (3.9, 5.0)

# %% [markdown]
# ### 과제 2
# - 구글링을통해 축 전환에 대해서 확인해 주시고 코드로 작성해 주세요!

# %% [markdown]
# ### 눈금값 설정 , 범례 설정
# xticks
# yticks
#
# ### 범례
# legend

# %%
plt.scatter([1,2,3],[4,5,6])
plt.xticks([1,2,3],['coupang','b','c'])
# Out:
# ([<matplotlib.axis.XTick at 0x134839590>,
#   <matplotlib.axis.XTick at 0x134800fd0>,
#   <matplotlib.axis.XTick at 0x134b34c10>],
#  [Text(1, 0, 'coupang'), Text(2, 0, 'b'), Text(3, 0, 'c')])

# %%
plt.scatter([1,2,3],[4,5,6], label= 'x=1') #라벨 설정
plt.scatter([-1,-1,-1],[4,5,6], label= 'x=-1')
plt.legend()#라벨 출력

# %% [markdown]
# - 범례 위치 중요함!
#
# - left
# - center
# - right
# - upper left
# - upper center
# - upper right
# - lower left
# - lower center
# - lower right

# %%
plt.scatter([1,2,3],[4,5,6], label= 'x=1') #라벨 설정
plt.scatter([-1,-1,-1],[4,5,6], label= 'x=-1')
plt.legend(loc = 'upper center')#라벨 출력

# %% [markdown]
# ### 그래프 크기 및 스타일 설정!
# - 그래프 크기는 figure 함수의 figsize  설정
# - 가로 세로 설정!

# %%
plt.figure(figsize=(10,5))
plt.scatter([1,2,3],[4,5,6])

# %%
##스타일 바꾸기
import seaborn as sns 
sns.set()#기본값은 (style='darkgrid')
plt.scatter([1,2,3],[4,5,6])

# %%
sns.set(style ='whitegrid')#기본값은 (style='darkgrid')
plt.scatter([1,2,3],[4,5,6])

# %% [markdown]
# ### 과제 2
# - sns.set() 다양한 함수들을 찾아서 5개 이상 공유해 주세요!

# %% [markdown]
# ### 다양한 그래프 그려보기!

# %%
plt.plot([1,2,3],[4,5,6], label= 'line1')
plt.plot([1,2,3],[7,8,9], label= 'line2')
plt.legend()

# %%
## 색상설정 #구글링하시면 색상도 여러가지가 있으니 확인해 주세요!
plt.plot([1,2,3],[4,5,6], color = 'blue', label= 'line1')
plt.plot([1,2,3],[7,8,9], color = 'brown', label= 'line2')
plt.legend()

# %%
## 선스타일 두께 등 설정
plt.plot([1,2,3],[4,5,6],linestyle= 'dashed', linewidth = 5,color = 'blue', label= 'line1')
plt.plot([1,2,3],[7,8,9],linestyle= 'dotted',linewidth = 3,color = 'brown', label= 'line2')

# %%
## 마커설정 점, 원, 다이아몬드, 사각형, 별  
## . 점 , o 원, s 사각형, * 별 D 다이아몬드, d 슬림한 다이아몬드
plt.plot([1,2,3],[4,5,6], marker='s', markersize=10)
plt.plot([1,2,3],[7,8,9], marker='d', markersize=10)

# %% [markdown]
# ### 산점도

# %%
#그래프마다 디자인하는 요소가 다르기 때문에 꼭 체크하기! 
plt.scatter([1,2,3],[4,5,6], marker='s', s=100, color='red')
plt.scatter([1,2,3],[7,8,9], marker='d', s=50, color= 'blue')

# %%
### 투명도
import numpy as np

# %%
x = np.random.normal(0,1,10000)
y = np.random.normal(0,1,10000)

# %%
x
# Out:
# array([-0.2793082 , -0.75542287, -0.58872235, ...,  0.41660443,
#        -1.30014614,  0.8008016 ])

# %%
y
# Out:
# array([-0.17134388,  1.74224891, -2.02594882, ..., -0.16364653,
#         0.50726459, -0.60672504])

# %%
plt.scatter(x,y, alpha=0.03) # 투명도는 alpha를 이용해서 조정

# %% [markdown]
# ## 막대그래프
# - bar

# %%
plt.bar(range(3), [20,30,40])
# Out:
# <BarContainer object of 3 artists>

# %%
##눈금값 설정
plt.bar(range(3), [20,30,40])
plt.xticks(range(3), ['english','math','science'])
# Out:
# ([<matplotlib.axis.XTick at 0x146c2e4d0>,
#   <matplotlib.axis.XTick at 0x146cc6350>,
#   <matplotlib.axis.XTick at 0x146ca79d0>],
#  [Text(0, 0, 'english'), Text(1, 0, 'math'), Text(2, 0, 'science')])

# %%
##스타일 설정 
plt.bar(range(3), [20,30,40], width= 0.5, color='orange',linewidth = 4.5)
# Out:
# <BarContainer object of 3 artists>

# %%
##스타일 설정 
plt.bar(range(3), [20,30,40], width= 0.5, color=['orange','blue','black'],linewidth = 4.5)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ## 박스플롯

# %%
x = np.random.normal(10,2,100)

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x146fb8c10>,
#   <matplotlib.lines.Line2D at 0x146fd98d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x146fda4d0>,
#   <matplotlib.lines.Line2D at 0x146fdaed0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x146fa16d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x146fdb950>],
#  'fliers': [<matplotlib.lines.Line2D at 0x146bfb090>],
#  'means': []}

# %%
x = np.random.normal(10,2,100)
y = np.random.normal(10,2,100)

# %%
plt.boxplot([x,y])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x147841c10>,
#   <matplotlib.lines.Line2D at 0x147842690>,
#   <matplotlib.lines.Line2D at 0x14784a750>,
#   <matplotlib.lines.Line2D at 0x14784b190>],
#  'caps': [<matplotlib.lines.Line2D at 0x147843150>,
#   <matplotlib.lines.Line2D at 0x147843cd0>,
#   <matplotlib.lines.Line2D at 0x14784bc90>,
#   <matplotlib.lines.Line2D at 0x14785c650>],
#  'boxes': [<matplotlib.lines.Line2D at 0x146fd8310>,
#   <matplotlib.lines.Line2D at 0x147849e50>],
#  'medians': [<matplotlib.lines.Line2D at 0x1478487d0>,
#   <matplotlib.lines.Line2D at 0x14785d210>],
#  'fliers': [<matplotlib.lines.Line2D at 0x146f26e90>,
#   <matplotlib.lines.Line2D at 0x14785dc10>],
#  'means': []}

# %%
#스타일설정
plt.boxplot([x,y])
plt.xticks([1,2], ['mpg','csv'])
# Out:
# ([<matplotlib.axis.XTick at 0x147891050>,
#   <matplotlib.axis.XTick at 0x14787cf10>],
#  [Text(1, 0, 'mpg'), Text(2, 0, 'csv')])

# %% [markdown]
# ## 히스토그램

# %%
x
# Out:
# array([12.23628554,  8.32646315,  7.46922261, 11.65319065,  8.27090397,
#        10.88406187,  9.22075523,  9.37892872, 10.23003298,  7.7975556 ,
#         8.16332463, 12.4013676 , 10.29109785, 13.39733423, 10.52286855,
#        10.35347681, 11.74711011,  9.55971175, 10.53918317,  8.44883114,
#        12.80070619,  7.77284157,  8.16218301, 10.57028029, 10.87044609,
#        14.48357545, 11.7958119 , 11.33412164, 10.01826653,  4.03803911,
#         8.96235797, 10.06451384, 12.70761239,  9.44423382, 12.12964714,
#        10.25583167,  8.56552959,  6.87377241,  9.87969234,  6.92446966,
#         7.56149554,  9.33609537,  8.11391506, 10.07221622,  9.05923788,
#        12.27995843, 10.57086829, 10.96434386,  8.50510895,  7.30633585,
#         9.13823572,  9.31100758, 11.72436   ,  4.11187871,  7.77948701,
#         8.45817358, 10.97537242, 10.41756408, 11.61590643,  9.91181015,
#         7.35318963, 11.46025648,  7.22582428,  8.89659698,  9.17558404,
#        10.65938247, 11.90664256,  9.60788016,  9.53021679, 12.54227923,
#        12.21957552, 10.50280064,  6.83443921,  9.29493475,  8.19203183,
#        12.90724236,  9.77353035,  7.70581056,  9.24197191,  9.41768164,
#         9.2633801 ,  9.24851828, 12.4497516 , 10.36412554,  8.84784351,
#        11.20786066, 10.26342737,  6.66085383, 12.74161463,  6.47087766,
#        10.0548676 ,  9.98912904, 10.97550486, 10.02138247, 11.74429517,
#        10.59679536, 10.69467661,  9.31348539,  9.15504389,  7.04281995])

# %%
plt.hist(x)
# Out:
# (array([ 2.,  0.,  6., 13., 16., 24., 18., 12.,  8.,  1.]),
#  array([ 4.03803911,  5.08259275,  6.12714638,  7.17170001,  8.21625365,
#          9.26080728, 10.30536091, 11.34991455, 12.39446818, 13.43902181,
#         14.48357545]),
#  <BarContainer object of 10 artists>)

# %%
##구간 개수 설정 bins =  
plt.hist(x, bins = 30 )
# Out:
# (array([ 2.,  0.,  0.,  0.,  0.,  0.,  1.,  1.,  4.,  4.,  5.,  4.,  5.,
#          3.,  8., 11.,  3., 10.,  9.,  7.,  2.,  3.,  5.,  4.,  5.,  2.,
#          1.,  0.,  0.,  1.]),
#  array([ 4.03803911,  4.38622366,  4.7344082 ,  5.08259275,  5.43077729,
#          5.77896184,  6.12714638,  6.47533092,  6.82351547,  7.17170001,
#          7.51988456,  7.8680691 ,  8.21625365,  8.56443819,  8.91262274,
#          9.26080728,  9.60899183,  9.95717637, 10.30536091, 10.65354546,
#         11.00173   , 11.34991455, 11.69809909, 12.04628364, 12.39446818,
#         12.74265273, 13.09083727, 13.43902181, 13.78720636, 14.1353909 ,
#         14.48357545]),
#  <BarContainer object of 30 artists>)

# %%
plt.hist(x, bins = 20 )
# Out:
# (array([ 2.,  0.,  0.,  0.,  1.,  5.,  5.,  8.,  6., 10., 12., 12., 11.,
#          7.,  7.,  5.,  7.,  1.,  0.,  1.]),
#  array([ 4.03803911,  4.56031593,  5.08259275,  5.60486956,  6.12714638,
#          6.6494232 ,  7.17170001,  7.69397683,  8.21625365,  8.73853046,
#          9.26080728,  9.7830841 , 10.30536091, 10.82763773, 11.34991455,
#         11.87219136, 12.39446818, 12.916745  , 13.43902181, 13.96129863,
#         14.48357545]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# ### 히트맵
# - 2차원 배열의 각 요소를 색상으로 시각화 하는 것

# %%
df = pd.DataFrame({'Math':[100,80,90],
                  'English':[60,50,70]},
                 index=['A','B','C'])

# %%
df
# Out:
#    Math  English
# A   100       60
# B    80       50
# C    90       70

# %%
sns.heatmap(df)

# %%
sns.heatmap(df)
plt.xticks([0.5,1.5],['', '영어'])
# Out:
# ([<matplotlib.axis.XTick at 0x7f808d1001d0>,
#   <matplotlib.axis.XTick at 0x7f808d0f13d0>],
#  <a list of 2 Text xticklabel objects>)
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 54617 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 50689 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 50612 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 54617 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 50689 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 50612 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
#데이터 표시! annot True 박스와 대응되는 데이터 표시 , fmt 데이터를 어떻게 표시할지 d 정수, .3f 소수점 셋째 
sns.heatmap(df, annot= True, fmt='d')

# %%
#데이터 표시! annot True 박스와 대응되는 데이터 표시 , fmt 데이터를 어떻게 표시할지 d 정수, .3f 소수점 셋째 
sns.heatmap(df, annot= True, fmt='d', linewidth = 1, linecolor='black')

# %%
# 컬럽맵 Greys, Blues, Reds 
sns.heatmap(df, annot= True, fmt='d', linewidth = 1, linecolor='black', cmap='Blues')

# %% [markdown]
# ## 공유드린 재무제표 데이터를 시각화로 표현해 주세요. 과제3
# - 가설을 설정, 분석 목적을 정하고 시각화를 진행해서 나온 결과를 해석하는 글과 함께 코드를 작성해 주세요.
